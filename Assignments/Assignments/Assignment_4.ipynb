# %% [markdown]
# # <center> Assignment-4 (75 marks)

# %% [markdown]
# #General Information

# %% [markdown]
# Welcome to Assignment 4! We will be applying the concepts we have learned so far to solve this assignment.Goodluck!
#
# Please fill out your name and email in the below cell

# %%
#NAME : 
#EMAIL :

# %% [markdown]
# #Question 1: (5 Marks)
#
# **In layman's Terms differentiate Supervised,Unsupervised and Reinforcement learning on the criteria of Supervision, Aim and Type of Data.**

# %%
#Ans

# %% [markdown]
# #Question 2: (10 Marks)

# %% [markdown]
# **Give a brief idea about Open AI and Gym Environments.Also differentiate Gym Environments with Custom Environments in detail.**

# %%
#Answer

# %% [markdown]
# #Question 3: (5 Marks)
# **List out challenges on working with RL Algorithms and handling of environments.**

# %%
#Ans

# %% [markdown]
# #Question 4: (5 Marks)

# %% [markdown]
# **List Out various Approaches to implement Reinforcement Learning Algorithms.**

# %%
#Ans

# %% [markdown]
# #Question 5: (10 Marks)

# %% [markdown]
# **Briefly interpret the given environment about observation space.And give approximation about what could be the possible action space for the agent dipicted at Starting state.**
#
# ![image.png](data:image/png;base64,...)

# %%
#Ans

# %% [markdown]
# #Question 6: (10 Marks)(Coding)

# %% [markdown]
# **Create Transition matrix for the given Markov Table using Numpy array**
#
# ![image.png](data:image/png;base64,...)

# %%
#Ans

# %% [markdown]
# #Question 7:(5 Marks)
# **Briefly write down different types of Policy in RL World**

# %%
#Ans

# %% [markdown]
# #Question 8:(10 Marks)
# **why should we care about immediate and future rewards? and Explain this fact with various discount factor limits.**

# %%
#Ans

# %% [markdown]
# #Question 9:(5 Marks)(Coding)
# **Import the "Taxi" Toy Text Environment from Gym and interpret its action space and observation space.**

# %%
#Ans

# %% [markdown]
# #Question 10:(10 Marks)(Coding)
# **Obtain Optimal Policy by Value Iteration  for "Taxi" Toy Text Environment.Assume discount factor as 1.0 and Maximum iterations allowable is 100.**

# %%
#Ans
